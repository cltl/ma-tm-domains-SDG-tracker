# %% [markdown]
# ## Extracting relevant articles

# %%
#2-step keyword extraction
#Text Mining Domains, VU

import pickle
import glob
import pandas as pd
import json
import os
import random
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords

def new_dict_concat_six (unpickled_dict):
    '''
    takes an unpickled dictionary as input with headline as [1] and list of first five sentences as [2]
    converts to a new dict with same key but value is string of concatenated headline + first five sentences
    filters the values of the keywords
    reurns: new dictionary with keys and concatenated headlines and first_five sentences of those articles which 
        contain the keywords
    '''        
    output = [unpickled_dict[key][1]+ '. ' + ' '.join(unpickled_dict[key][2]) for key in unpickled_dict]
    
    # calling test_dict only gets keys
    new_dict = dict(zip(unpickled_dict, output))
    
    return new_dict

def no_filter(infolder):
    '''Reads all pickles files, converts them to .json'''
    for file in glob.glob(infolder):
        #prep filepaths for writing files
        path = os.path.split(file)[0].split('/')[0]
        basename = os.path.basename(file)

        unpickled_dict = pickle.load(open (file, 'rb'))
        #print(unpickled_dict)
        # run the function above to concat headlines and first_five
        new_dict = new_dict_concat_six(unpickled_dict)

        #write filtered articles - choosing json this time so I can inspect them in IDE
        if not os.path.exists(f'filteredpickles/unfiltered'):
            os.makedirs(f'filteredpickles/unfiltered')

        with open(f'filteredpickles/unfiltered/{basename.rstrip(".gz.pkl")}.json', 'w', encoding = 'utf-8') as outfile:
            json.dump(new_dict, outfile)
                  
def keyword_search(keywords, big_df, treshold = 0):
    '''Loads a (hand-crafted) SDG-specific keyword list.
    Filters all articles containing 'treshold' or more members of the keyword list
    Returns a dataframe containing relevant articles.'''
#phase 2 of keyword search
    article_dictlist = []
    #do a keyword search for the company
    i = 0
    for text in big_df['text']:
        keywords_found = set()
        for keyword in keywords:
            if keyword in text:
                keywords_found.add(keyword)
        if len(keywords_found) >= treshold:
            article_dict = {'identifier' : big_df.index[i], 'text' : text, 'keywords' : keywords_found}
            article_dictlist.append(article_dict)
        i += 1
    articles = pd.DataFrame(article_dictlist)
    return articles

# %%
#create json files for all subcorpora
#needs to be run once on your system
#no_filter(infolder)

# %% [markdown]
# ## Retrieving Tf-idf scores for keywords

# %%
#Retrieve random articles to balance tf-idf scores for keywords

def random_sample(n):
    '''Returns a random sample, containing n articles'''
    df_list = []
    i = 0
    path = "filteredpickles/unfiltered"
    while i < 50:
        filename = random.choice(os.listdir(path))
        jsonners = json.load(open(f'{path}/{filename}', 'rb'))
        df_list.append(pd.DataFrame.from_dict(jsonners, orient = 'index', columns = ['text']))
        i+=1
    random_df = pd.concat(df_list)
    random_sample = random_df.sample(n = n)
    return random_sample

# %%
#create json files for all subcorpora, needed for random sampling
#no_filter(infolder)

# %% [markdown]
# Compute tf-idf scores for keywords in relevant articles

# %%
def compute_tf_idf(articles, keywordlist):
    '''This function computes tf-idf scores for all terms in :keywordlist that are in each article'''
    random_df = random_sample(30000)
    mixed_df = pd.concat([articles,random_df])
    
    stopWords = set(stopwords.words('english'))
    #train and apply tfidf
    #may take a while
    vectorizer = TfidfVectorizer(stop_words = stopWords, ngram_range = (1,2))
    tf_idf_vecs = vectorizer.fit_transform(mixed_df['text'])
    #last step: get tfidf scores for keywords in selected articles    
    doc_scores = []

    keywords_corpus = []
    for keyword in keywordlist:
        if keyword in vectorizer.get_feature_names():
            keywords_corpus.append(keyword)
    print('keywords used:', keywords_corpus)
    
    for i in range(len(articles)):
        df = pd.DataFrame(tf_idf_vecs[i].T.todense(), index=vectorizer.get_feature_names(), columns=["tfidf"])
        df = df.sort_values(by=["tfidf"], ascending=False)
        #print(df)
        doc_score = 0
        keywords_found = set()
        for keyword in keywords_corpus:
            keyword_score = df['tfidf'][keyword]
            if keyword_score > 0:
                keywords_found.add(keyword)
                doc_score += keyword_score
        doc_scores.append(doc_score)
        
    scores_df = pd.DataFrame(doc_scores, columns = ['Score'])
    articles = pd.concat([articles, scores_df], axis = 1)
    articles = articles.set_index('identifier')
    articles = articles.sort_values(by="Score", ascending = False)
    return articles

# %%
def keyword_search_tf_idf(topic, treshold):
    '''This function guides the full process of extracting relevant articles using keyword_search, and '''
    #retrieve keyword list
    with open(f'keywords/{topic}.txt', 'r', encoding = 'utf-8') as infile:
        keywords = infile.read().splitlines()

    #scrape relevant articles (keyword search)
    df_list = []
    for file in glob.glob('filteredpickles/unfiltered/*'):
        jsonners = json.load(open(file, 'rb'))
        df = pd.DataFrame.from_dict(jsonners, orient='index', columns= ['text'])
        relevant_articles = keyword_search(keywords, df, treshold = treshold)
        df_list.append(relevant_articles)
    #concatenate all relevant articles into one dataframe    
    big_df = pd.concat(df_list, ignore_index = True)
    #write search results to a csv file
    with open(f'results/keyword_lookup_{topic}_t{treshold}.csv', 'w', encoding = 'utf-8') as outfile:
        outfile.write(big_df.to_csv())
        
    #compute tf-idf scores of keywords in relevant articles
    articles = compute_tf_idf(big_df, keywords)
    with open(f'results/keyword_lookup_tfidf_{topic}_t{treshold}_bigrams.csv', 'w', encoding = 'utf-8') as outfile:
        outfile.write(articles.to_csv())
    
    return articles

# %% [markdown]
# Keyword search and TF-IDF-based ranking

# %%
topic = 'sustainable consumption'
treshold = 3
articles = keyword_search_tf_idf(topic, treshold)
articles
# Out:
# keywords used: ['sustainable consumption', 'sustainable production', 'efficiency', 'waste management', 'recycling', 'reuse', 'sustainability', 'procurement', 'awareness', 'sustainable tourism', 'local culture', 'local products', 'local production']
#                                                                     text  \
# identifier
# CNA_ENG_20080516.0038  Taiwan's recycling shines on international sta...
# NYT_ENG_20020312.0012  IN NEW YORK CITY, DOING WELL TRUMPS DOING GOOD...
# XIN_ENG_20050112.0044  HK to build Recovery Park for recycling indust...
# XIN_ENG_20041030.0279  Clean-up campaign launched in Kathmandu Valley...
# XIN_ENG_20070607.0278  IDB approves 60 million-dollar loan to attract...
# XIN_ENG_20021003.0434  Thailand supports local production of aromatic...
# WPB_ENG_20100525.0072  Wal-Mart's `Green' Muscle Fuels Unruh's Goal o...
# XIN_ENG_20080627.0103  Feature: World's tourism industry grapples wit...
# XIN_ENG_20101106.0059  World dairy summit in New Zealand eyes sustain...
# XIN_ENG_20101013.0464  EU calls for cooperation with Asia for SMEs su...
# XIN_ENG_20091115.0137  (Universal Children's Day) Feature: Jordan's d...
# XIN_ENG_20090318.0380  Highest eco-level required for new HKSAR gov't...
# APW_ENG_20070905.1543  Coca-Cola announces new plant, sets 100 percen...
# WPB_ENG_20101028.0037  Australian Landlords Prepare for New Energy Ef...
# XIN_ENG_20090830.0231  Beijing sets "recycling" day and offers door-t...
# XIN_ENG_20070301.0054  World Bank approves loan for east China's envi...
# XIN_ENG_19950119.0049  Canadian Government Supports Sand Recycling Sy...
# NYT_ENG_20070417.0259  WANT EPA HOTEL AND CONVENTION CENTER BUSINESS?...
# CNA_ENG_20050829.0018  EPA TRYING TO TACKLE ILLEGAL FACTORY DUMPING O...
# XIN_ENG_20010830.0183  HK to Hold Road Shows on Waste Reduction. The ...
# AFP_ENG_20080809.0576  Olympics: Yao becomes UN environment campaigne...
# XIN_ENG_19970915.0086  Global Communities Urged to Clean up Local. Th...
# XIN_ENG_19950204.0007  European Commission Funds Environmental Projec...
# XIN_ENG_20100513.0241  Roundup: Sustainable resource use tops debate ...
# CNA_ENG_20080424.0039  Government to promote 'green technology' among...
# XIN_ENG_20030605.0213  ADB provides Mozambique with 33 million dollar...
# XIN_ENG_20030219.0056  UNEP official wins Chinese environmental award...
# XIN_ENG_20080418.0237  Hong Kong launches cleaner production scheme. ...
# XIN_ENG_20100930.0198  Swedish cleantech innovators want to tap Chine...
# XIN_ENG_20071118.0063  Experts seek "green solution" to garbage dispo...
# XIN_ENG_20080227.0121  Plan to recycle schoolbooks gets mixed recepti...
# NYT_ENG_20000204.0266  Mohawk to buy plastic bottles from Coke bottle...
# XIN_ENG_20060604.0213  Full text: Environmental Protection in China (...
# XIN_ENG_20071225.0254  Full Text: China's Energy Conditions and Polic...
# XIN_ENG_20070322.0231  UN chief calls for integrated management of wa...
# NYT_ENG_20050704.0206  TRASH REMOVAL GOAL MIGHT BE DUMPED. The amount...
#
#                                                                 keywords  \
# identifier
# CNA_ENG_20080516.0038                 {efficiency, recycling, awareness}
# NYT_ENG_20020312.0012                      {awareness, reuse, recycling}
# XIN_ENG_20050112.0044                    {procurement, reuse, recycling}
# XIN_ENG_20041030.0279    {waste management, awareness, reuse, recycling}
# XIN_ENG_20070607.0278  {waste management, awareness, sustainable tour...
# XIN_ENG_20021003.0434      {awareness, local products, local production}
# WPB_ENG_20100525.0072  {efficiency, sustainability, sustainable produ...
# XIN_ENG_20080627.0103  {sustainable tourism, local culture, sustainab...
# XIN_ENG_20101106.0059                 {sustainability, reuse, recycling}
# XIN_ENG_20101013.0464  {sustainable consumption, awareness, sustainab...
# XIN_ENG_20091115.0137      {sustainability, reuse, recycling, awareness}
# XIN_ENG_20090318.0380  {waste management, efficiency, sustainability,...
# APW_ENG_20070905.1543                      {awareness, reuse, recycling}
# WPB_ENG_20101028.0037            {efficiency, sustainability, recycling}
# XIN_ENG_20090830.0231                 {efficiency, recycling, awareness}
# XIN_ENG_20070301.0054     {waste management, efficiency, sustainability}
# XIN_ENG_19950119.0049            {efficiency, sustainability, recycling}
# NYT_ENG_20070417.0259        {efficiency, procurement, reuse, recycling}
# CNA_ENG_20050829.0018          {waste management, efficiency, recycling}
# XIN_ENG_20010830.0183           {waste management, awareness, recycling}
# AFP_ENG_20080809.0576          {waste management, efficiency, awareness}
# XIN_ENG_19970915.0086               {waste management, awareness, reuse}
# XIN_ENG_19950204.0007           {waste management, awareness, recycling}
# XIN_ENG_20100513.0241      {waste management, awareness, sustainability}
# CNA_ENG_20080424.0039          {waste management, efficiency, recycling}
# XIN_ENG_20030605.0213      {waste management, awareness, sustainability}
# XIN_ENG_20030219.0056       {sustainable tourism, efficiency, awareness}
# XIN_ENG_20080418.0237               {efficiency, procurement, awareness}
# XIN_ENG_20100930.0198     {waste management, efficiency, sustainability}
# XIN_ENG_20071118.0063          {waste management, efficiency, awareness}
# XIN_ENG_20080227.0121                      {awareness, reuse, recycling}
# NYT_ENG_20000204.0266         {waste management, procurement, recycling}
# XIN_ENG_20060604.0213         {recycling, reuse, sustainable production}
# XIN_ENG_20071225.0254               {efficiency, procurement, awareness}
# XIN_ENG_20070322.0231  {sustainable consumption, efficiency, sustaina...
# NYT_ENG_20050704.0206               {waste management, reuse, recycling}
#
#                           Score
# identifier
# CNA_ENG_20080516.0038  0.617393
# NYT_ENG_20020312.0012  0.445192
# XIN_ENG_20050112.0044  0.426368
# XIN_ENG_20041030.0279  0.385239
# XIN_ENG_20070607.0278  0.349732
# XIN_ENG_20021003.0434  0.299095
# WPB_ENG_20100525.0072  0.267863
# XIN_ENG_20080627.0103  0.267011
# XIN_ENG_20101106.0059  0.261911
# XIN_ENG_20101013.0464  0.261024
# XIN_ENG_20091115.0137  0.250788
# XIN_ENG_20090318.0380  0.242998
# APW_ENG_20070905.1543  0.226365
# WPB_ENG_20101028.0037  0.218841
# XIN_ENG_20090830.0231  0.217269
# XIN_ENG_20070301.0054  0.213921
# XIN_ENG_19950119.0049  0.211974
# NYT_ENG_20070417.0259  0.199388
# CNA_ENG_20050829.0018  0.193390
# XIN_ENG_20010830.0183  0.187304
# AFP_ENG_20080809.0576  0.182775
# XIN_ENG_19970915.0086  0.177925
# XIN_ENG_19950204.0007  0.175268
# XIN_ENG_20100513.0241  0.173048
# CNA_ENG_20080424.0039  0.172611
# XIN_ENG_20030605.0213  0.170118
# XIN_ENG_20030219.0056  0.160492
# XIN_ENG_20080418.0237  0.155914
# XIN_ENG_20100930.0198  0.152338
# XIN_ENG_20071118.0063  0.144562
# XIN_ENG_20080227.0121  0.143737
# NYT_ENG_20000204.0266  0.134384
# XIN_ENG_20060604.0213  0.133776
# XIN_ENG_20071225.0254  0.133519
# XIN_ENG_20070322.0231  0.105254
# NYT_ENG_20050704.0206  0.087320

# %%
topic = 'gender equality'
treshold = 3
articles = keyword_search_tf_idf(topic, treshold)
articles
# Out:
# keywords used: ['gender equality', 'discrimination', 'violence', 'trafficking', 'exploitation', 'sexual exploitation', 'forced marriage', 'genital mutilation', 'domestic work', 'public services', 'shared responsibility', 'participation', 'equal opportunities', 'leadership']
#                                                                     text  \
# identifier
# XIN_ENG_20020918.0091  Cambodia to enhance law enforcement against tr...
# AFP_ENG_20051026.0765  US official slams UN on troops' child sex abus...
# XIN_ENG_20030612.0151  US tags Philippines as main source of human tr...
# AFP_ENG_20011220.0236  Youth speak out against sexual exploitation. Y...
# XIN_ENG_20011009.0137  Cambodia Combats Trafficking, Sexual Exploitat...
# ...                                                                  ...
# APW_ENG_20070601.1127  Philadelphia council says city can end Boy Sco...
# LTW_ENG_19970208.0021  U.S. Revises Plan for All-African Military For...
# XIN_ENG_20030725.0130  Program of Action for Sustainable Development ...
# NYT_ENG_19990604.0340  EDITORIAL: EUROPE'S NEW MILITARY ASPIRATIONS. ...
# XIN_ENG_19971216.0180  Chinese President Jiang's Speech at Informal C...
#
#                                                                 keywords  \
# identifier
# XIN_ENG_20020918.0091   {trafficking, sexual exploitation, exploitation}
# AFP_ENG_20051026.0765   {trafficking, sexual exploitation, exploitation}
# XIN_ENG_20030612.0151   {trafficking, sexual exploitation, exploitation}
# AFP_ENG_20011220.0236  {sexual exploitation, discrimination, exploita...
# XIN_ENG_20011009.0137   {trafficking, sexual exploitation, exploitation}
# ...                                                                  ...
# APW_ENG_20070601.1127        {participation, discrimination, leadership}
# LTW_ENG_19970208.0021         {decision-making, violence, participation}
# XIN_ENG_20030725.0130  {public services, participation, decision-making}
# NYT_ENG_19990604.0340       {participation, leadership, decision-making}
# XIN_ENG_19971216.0180   {participation, discrimination, decision-making}
#
#                           Score
# identifier
# XIN_ENG_20020918.0091  0.585917
# AFP_ENG_20051026.0765  0.563182
# XIN_ENG_20030612.0151  0.562675
# AFP_ENG_20011220.0236  0.534778
# XIN_ENG_20011009.0137  0.525071
# ...                         ...
# APW_ENG_20070601.1127  0.065091
# LTW_ENG_19970208.0021  0.063783
# XIN_ENG_20030725.0130  0.062764
# NYT_ENG_19990604.0340  0.060213
# XIN_ENG_19971216.0180  0.058129
#
# [863 rows x 3 columns]

# %%
topic = 'poverty'
treshold = 5
articles = keyword_search_tf_idf(topic, treshold)
articles
# Out:
# keywords used: ['poverty', 'social protection', 'protection systems', 'protection measures', 'vulnerable', 'equal rights', 'economic resources', 'poor', 'ownership', 'control', 'property', 'resilience', 'exposure', 'shocks', 'disasters', 'mobilization', 'development cooperation', 'adequate means', 'poverty eradication', 'human rights', 'working conditions', 'inhuman', 'workers', 'fair wage', 'extortion', 'slavery', 'famine', 'minimum wage', 'child labor', 'hunger', 'entrepreneur', 'free education', 'low wage', 'development', 'social security', 'natural disaster']
#                                                                     text  \
# identifier
# XIN_ENG_20070628.0209  Officials say relocation only effective remedy...
# XIN_ENG_20071123.0250  Niger hosts UN strategic meeting on poverty er...
# APW_ENG_19960920.0621  Agricultural Workers Get Poor Pay, Poor Protec...
# XIN_ENG_20081209.0269  Full Text: Wang Chen: China Registers Historic...
# APW_ENG_19960920.0682  FOR RELEASE AT 0100 GMT MONDAY, TIME SET BY SO...
# ...                                                                  ...
# NYT_ENG_19990709.0227  UNDATED: productivity increases.. ``When there...
# NYT_ENG_20051003.0237  GAP WIDENS BETWEEN HAVES AND HAVE-NOTS. The in...
# APW_ENG_20031209.0770  Recent winners of the Nobel Memorial Prize in ...
# XIN_ENG_20090511.0238  Full text: China's Actions for Disaster Preven...
# APW_ENG_19950921.1116  None. was based on an intention to preserve th...
#
#                                                                 keywords  \
# identifier
# XIN_ENG_20070628.0209  {workers, poverty eradication, poverty, develo...
# XIN_ENG_20071123.0250  {mobilization, poverty eradication, poverty, d...
# APW_ENG_19960920.0621  {social protection, workers, working condition...
# XIN_ENG_20081209.0269  {control, poverty, hunger, development, poor, ...
# APW_ENG_19960920.0682  {social protection, workers, working condition...
# ...                                                                  ...
# NYT_ENG_19990709.0227  {control, entrepreneur, poverty, development, ...
# NYT_ENG_20051003.0237  {workers, control, entrepreneur, development, ...
# APW_ENG_20031209.0770  {famine, control, property, development, poverty}
# XIN_ENG_20090511.0238  {disasters, workers, control, development, nat...
# APW_ENG_19950921.1116  {famine, disasters, control, development, huma...
#
#                           Score
# identifier
# XIN_ENG_20070628.0209  0.656799
# XIN_ENG_20071123.0250  0.616652
# APW_ENG_19960920.0621  0.604646
# XIN_ENG_20081209.0269  0.595886
# APW_ENG_19960920.0682  0.594786
# ...                         ...
# NYT_ENG_19990709.0227  0.077821
# NYT_ENG_20051003.0237  0.073776
# APW_ENG_20031209.0770  0.071433
# XIN_ENG_20090511.0238  0.069701
# APW_ENG_19950921.1116  0.059174
#
# [465 rows x 3 columns]
